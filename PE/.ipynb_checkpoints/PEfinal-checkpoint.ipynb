# %%
import pandas as pd

dataset = pd.read_csv("PEdata.csv",sep='|')

# %%
dataset.columns
# Out:
# Index(['Name', 'md5', 'Machine', 'SizeOfOptionalHeader', 'Characteristics',
#        'MajorLinkerVersion', 'MinorLinkerVersion', 'SizeOfCode',
#        'SizeOfInitializedData', 'SizeOfUninitializedData',
#        'AddressOfEntryPoint', 'BaseOfCode', 'BaseOfData', 'ImageBase',
#        'SectionAlignment', 'FileAlignment', 'MajorOperatingSystemVersion',
#        'MinorOperatingSystemVersion', 'MajorImageVersion', 'MinorImageVersion',
#        'MajorSubsystemVersion', 'MinorSubsystemVersion', 'SizeOfImage',
#        'SizeOfHeaders', 'CheckSum', 'Subsystem', 'DllCharacteristics',
#        'SizeOfStackReserve', 'SizeOfStackCommit', 'SizeOfHeapReserve',
#        'SizeOfHeapCommit', 'LoaderFlags', 'NumberOfRvaAndSizes', 'SectionsNb',
#        'SectionsMeanEntropy', 'SectionsMinEntropy', 'SectionsMaxEntropy',
#        'SectionsMeanRawsize', 'SectionsMinRawsize', 'SectionMaxRawsize',
#        'SectionsMeanVirtualsize', 'SectionsMinVirtualsize',
# ...

# %%
dataset.head()
# Out:
#            Name                               md5  Machine
# 0   memtest.exe  631ea355665f28d4707448e442fbf5b8      332  \
# 1       ose.exe  9d10f99a6712e28f8acd5641e3a7ea6b      332
# 2     setup.exe  4d92f518527353c0db88a70fddcfd390      332
# 3      DW20.EXE  a41e524f8d45f0074fd07805ff0c9b12      332
# 4  dwtrig20.exe  c87e561258f2f8650cef999bf643a731      332
#
#    SizeOfOptionalHeader  Characteristics  MajorLinkerVersion
# 0                   224              258                   9  \
# 1                   224             3330                   9
# 2                   224             3330                   9
# 3                   224              258                   9
# 4                   224              258                   9
#
#    MinorLinkerVersion  SizeOfCode  SizeOfInitializedData
# 0                   0      361984                 115712  \
# 1                   0      130560                  19968
# 2                   0      517120                 621568
# ...

# %%
dataset.tail()
# Out:
#                                                Name
# 138042  VirusShare_8e292b418568d6e7b87f2a32aee7074b  \
# 138043  VirusShare_260d9e2258aed4c8a3bbd703ec895822
# 138044  VirusShare_8d088a51b7d225c9f5d11d239791ec3f
# 138045  VirusShare_4286dccf67ca220fe67635388229a9f3
# 138046  VirusShare_d7648eae45f09b3adb75127f43be6d11
#
#                                      md5  Machine  SizeOfOptionalHeader
# 138042  8e292b418568d6e7b87f2a32aee7074b      332                   224  \
# 138043  260d9e2258aed4c8a3bbd703ec895822      332                   224
# 138044  8d088a51b7d225c9f5d11d239791ec3f      332                   224
# 138045  4286dccf67ca220fe67635388229a9f3      332                   224
# 138046  d7648eae45f09b3adb75127f43be6d11      332                   224
#
#         Characteristics  MajorLinkerVersion  MinorLinkerVersion  SizeOfCode
# 138042              258                  11                   0      205824  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138047 entries, 0 to 138046
# Data columns (total 57 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Name                         138047 non-null  object
#  1   md5                          138047 non-null  object
#  2   Machine                      138047 non-null  int64
#  3   SizeOfOptionalHeader         138047 non-null  int64
#  4   Characteristics              138047 non-null  int64
#  5   MajorLinkerVersion           138047 non-null  int64
#  6   MinorLinkerVersion           138047 non-null  int64
#  7   SizeOfCode                   138047 non-null  int64
#  8   SizeOfInitializedData        138047 non-null  int64
#  9   SizeOfUninitializedData      138047 non-null  int64
#  10  AddressOfEntryPoint          138047 non-null  int64
#  11  BaseOfCode                   138047 non-null  int64
# ...

# %%
dataset['legitimate'].value_counts()
# Out:
# legitimate
# 0    96724
# 1    41323
# Name: count, dtype: int64

# %%
X = dataset.drop(['legitimate','Name','md5'],axis=1).values
y = dataset['legitimate'].values

# %%
pip install pefile
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas
import numpy
import pickle
import pefile
import sklearn.ensemble as ek
from sklearn.feature_selection import SelectFromModel
import joblib
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn import svm
import sklearn.metrics as metrics

# %%
# important feature selection

extratrees = ek.ExtraTreesClassifier().fit(X,y)             # Classifier with data
selector = SelectFromModel(extratrees,prefit=True)          # It will select important features
X_new = selector.transform(X)                               # selected features from X
n_features = X_new.shape[1]                                 # count of X_new

# %%
n_features
# Out:
# 13

# %%
# print important features

features = []
index = numpy.argsort(extratrees.feature_importances_)[::-1][:n_features]    # features index

print(index)
# index array contains the indices of most important features in descending order of importance
# Out:
# [24  2  0 53 23 11  1 48 18 34 47 14 33]

# %%
# print selected features with importance


for f in range(n_features):
    print("%d. feature %s (%f)" % (f + 1, dataset.columns[2+index[f]], extratrees.feature_importances_[index[f]])) # +2 cuz we removed md5,name
    features.append(dataset.columns[2+f])
# Out:
# 1. feature DllCharacteristics (0.138224)
# 2. feature Characteristics (0.106416)
# 3. feature Machine (0.101925)
# 4. feature VersionInformationSize (0.072926)
# 5. feature Subsystem (0.070732)
# 6. feature ImageBase (0.063998)
# 7. feature SizeOfOptionalHeader (0.053241)
# 8. feature ResourcesMaxEntropy (0.048989)
# 9. feature MajorSubsystemVersion (0.046191)
# 10. feature SectionsMaxEntropy (0.041363)
# 11. feature ResourcesMinEntropy (0.030495)
# 12. feature MajorOperatingSystemVersion (0.026421)
# 13. feature SectionsMinEntropy (0.020738)

# %%
# splitting the data (70:30)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.30, stratify = y)

# %%
# finding the best classifier
# !pip install tpot
from tpot import TPOTClassifier
tpot = TPOTClassifier(
        generations=5,
        population_size=20,
        verbosity=2,
        random_state=42,
        config_dict='TPOT sparse',
        scoring='accuracy',
        cv=5
)
# Out:
# ...
# /home/suhani/anaconda3/lib/python3.11/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")

# %%
tpot.fit(X_new,y)
# Out:
# Optimization Progress:   0%|          | 0/120 [00:00<?, ?pipeline/s]
# Generation 1 - Current best internal CV score: 0.9851427183045531
#
# Generation 2 - Current best internal CV score: 0.9852151581885131
#
# Generation 3 - Current best internal CV score: 0.9852151581885131
#
# Generation 4 - Current best internal CV score: 0.9853962483219355
#
# Generation 5 - Current best internal CV score: 0.9853962483219355
#
# Best pipeline: XGBClassifier(CombineDFs(input_matrix, input_matrix), learning_rate=0.1, max_depth=3, min_child_weight=8, n_estimators=100, n_jobs=1, subsample=0.5, verbosity=0)
# TPOTClassifier(config_dict='TPOT sparse', generations=5, population_size=20,
#                random_state=42, scoring='accuracy', verbosity=2)

# %%
best_pipeline = tpot.fitted_pipeline_

# %%
test_accuracy = tpot.score(X_test,y_test)

from sklearn.metrics import accuracy_score, balanced_accuracy_score, precision_score, recall_score, f1_score

# Assuming you have a trained model 'model'
y_pred = best_pipeline.predict(X_test)

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
balanced_accuracy = balanced_accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

# Print the results
print(f"Accuracy: {accuracy:.4f}")
print(f"Balanced Accuracy: {balanced_accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Accuracy: 0.9902
# Balanced Accuracy: 0.9889
# Precision: 0.9818
# Recall: 0.9856
# F1 Score: 0.9837

# %%
# save features
open('F.pkl', 'wb').write(pickle.dumps(features))
# save model 
joblib.dump(best_pipeline, 'C.pkl')
#load model
loaded_model = joblib.load('C.pkl')
#load features
features = pickle.loads(open(os.path.join('F.pkl'),'rb').read())

# %%
# Use the loaded model to make predictions
predictions = loaded_model.predict(X_test)

from sklearn.metrics import confusion_matrix

# Plotting confusion matrix
cm = confusion_matrix(y_test, predictions)

plt.figure(figsize=(8, 8))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

classes = ['Class 0', 'Class 1']  # Replace with your actual class labels
tick_marks = range(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)

plt.xlabel('Predicted Label')
plt.ylabel('True Label')

for i in range(len(classes)):
    for j in range(len(classes)):
        plt.text(j, i, format(cm[i, j], 'd'), horizontalalignment="center", color="white" if cm[i, j] > cm.max() / 2 else "black")

plt.show()

# %%
# Plotting feature importances for all features in X in descending order

plt.figure(figsize=(14, 8))  

sorted_indices = numpy.argsort(extratrees.feature_importances_)[::-1]
sorted_importances = extratrees.feature_importances_[sorted_indices]
sorted_features = [dataset.columns[2 + i] for i in sorted_indices]

plt.bar(range(X.shape[1]), sorted_importances, align="center")
plt.xticks(range(X.shape[1]), sorted_features, rotation=90, ha='right')  
plt.xlabel("Feature")
plt.ylabel("Importance")
plt.title("Feature Importances (Descending Order)")
plt.tight_layout()  
plt.show()

# %%
selected_data = dataset.iloc[:, 2 + index[:n_features]]

# Calculate the correlation matrix for the selected features
correlation_matrix = selected_data.corr()

# Plot the correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap of Selected Features')
plt.show()
